# %%
import numpy as np
import pandas as pd
import random
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import euclidean_distances
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
iris = datasets.load_iris()

# %%
from load_iris_data import *
import math
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

# %%
z_scaler = lambda column: (column - column.mean())/ column.std()
scaled_data = pd.DataFrame()
scaled_data = df[["A", "B", "C", "D"]].apply(z_scaler, axis=0)
scaled_data["category"] = df["category"]
scaled_data[0:2]

# %%
y = np.array([1 if i == 'Iris-setosa' else 0 for i in scaled_data["category"]])
x = scaled_data[["A", "B", "C", "D"]]
x['E'] = 1
x = x.values
W = np.array([int(np.random.rand() * 10) for i in range(5)])

# %%
train_X, test_X, train_y, test_y = train_test_split(x, y, test_size = 0.25)
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

def calc_penalty(H):
    penalty = 0
    for i in range(len(H)):
        penalty += train_y[i] * np.log(H[i]) + (1 - train_y[i]) * (np.log(1 - H[i]))
    return -penalty / len(H)

# %%
for i in range(100):
    H = np.matmul(W.transpose(), train_X.transpose())
    H = np.array([sigmoid(i) for i in H])
    #print(calc_penalty(H))
    #print(W.shape, train_X.shape, train_y.shape, H.shape)
    nabla = -np.matmul((train_y - H).transpose(), train_X)
    #nabla.shape
    #print(W)
    W = W - 0.01 * nabla
print(W)
H = np.matmul(W.transpose(), train_X.transpose())
H = np.array([1 if i >= 0.5 else 0 for i in H])
print(H)
print(accuracy_score(train_y, H))

# %%
scaler = StandardScaler()
X = scaler.fit_transform(iris["data"])
y = iris["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 50)

# %%
class LogisticRegression(object):
    
    def __init__(self, X, y):
        self.H = []
        self.W = np.array([int(np.random.rand() * 10) for i in range(5)]).reshape(5, 1)
        self.X = np.array([np.append(row, 1) for row in X])
#         print(self.X)
        self.y = y.reshape(1, len(y))
#         print("W",self.W.shape)
        
#         print("y",self.y.shape)
    
    def sigmoid(self, x):
        return 1.0 / (1.0 + np.exp(-x))
    
    def train(self, epochs):
        for i in range(epochs):
            self.H = np.matmul(self.W.transpose(), self.X.transpose())
            print("H", self.H)
            self.H = np.array([self.sigmoid(h) for h in self.H])
            
#             print(self.y.shape)
#             print(self.H.shape)
#             print(self.X.shape)
            nabla = -np.matmul((self.y - self.H), self.X).transpose()
#             print("nabla",nabla.shape)
            self.W = self.W - 0.01 * nabla
    
    def predict(self, t):
        t = np.append(t, 1)
        prediction = np.matmul(self.W.transpose(), t.transpose())
        return self.sigmoid(prediction)

# %%
from sklearn.metrics import accuracy_score
obj = LogisticRegression(X_train, y_train)
obj.train(1000)
predictions = []
# print(obj.W)
# print(obj.X.shape)
# print(obj.y.shape)
# print(obj.H.shape)
for row in X_test:
    predictions.append(obj.predict(row))
predictions = np.array([1 if i >= 0.5 else 0 for i in predictions])
print(accuracy_score(y_test, predictions))
# Out:
# H [[  1.49037347  -6.4691766  -14.16768036  -7.24993195   8.16402815
#   -10.724094     8.29053623  -5.05330069  -8.69833302  -2.07306967
#     2.02362775   6.84410504   2.23015736  -1.08499953   2.63581715
#     1.10070623   2.86307189  -1.07673322   4.27384375  -5.53263196
#   -10.08675081   7.42668644  15.68350509   0.57938217   4.4842927
#    -5.23133426  -9.33033601   5.36397164   1.5231718   -5.13762451
#    -4.84697915  -2.02898063   6.09403134   5.93701266   3.04553413
#     5.88334623  -4.70898889  -8.39913158  -3.65017337  -2.02474344
#    -3.45856136   4.22956324  -8.1642323   -9.33033601   1.92561571
#    -9.42404576   1.13331308  -8.88784878  -3.19425449   4.53810593
#     5.06801414  10.44600456   0.99231503   2.69781499  -5.28285976
#     2.86307189 -10.97901494  -6.90744324  -3.51430744  11.89952628
#    -6.48404952  -6.28370656   4.36007236   4.4095016   10.63761657
#     9.77476002  -6.65464664  11.00726215  -1.83524429   2.30586001
# ...

# %%
W = np.array([int(np.random.rand() * 10) for i in range(5)]).reshape(5, 1)
W.shape
W.transpose().shape

# %%
X_train

# %%
x = np.array([i for i in range(10)])
x.shape

# %%
np.array([1,2]) - np.array([3,4])
